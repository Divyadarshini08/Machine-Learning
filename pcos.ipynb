# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyadarshini08/Machine-Learning/blob/main/pcos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/PCOS /PCOS final.csv')

# %%
df.isna()
# Out:
#      Sl. No  Patient File No.   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0     False             False       False        False        False
# 1     False             False       False        False        False
# 2     False             False       False        False        False
# 3     False             False       False        False        False
# 4     False             False       False        False        False
# ..      ...               ...         ...          ...          ...
# 536   False             False       False        False        False
# 537   False             False       False        False        False
# 538   False             False       False        False        False
# 539   False             False       False        False        False
# 540   False             False       False        False        False
#
#      Blood Group  Cycle(R/I)  Cycle length(days)  Marraige Status (Yrs)  \
# 0          False       False               False                  False
# ...

# %%
d1=df.head(135)
d2=df.head(270)
d3=df.head(405)

# %%
df.columns
# Out:
# Index(['Sl. No', 'Patient File No.', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'Blood Group', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'No. of aborptions', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'I beta-HCG(mIU/mL)', 'Fast food (Y/N)', 'LH(mIU/mL)',
#        'FSH(mIU/mL)', 'Reg.Exercise(Y/N)', 'Pregnant(Y/N)', 'PCOS (Y/N)'],
#       dtype='object')

# %%
df.fillna(0, inplace=True)

# %%
df.describe()
# Out:
#            Sl. No  Patient File No.   Age (yrs)  Weight (Kg)  Height(Cm)   \
# count  541.000000        541.000000  541.000000   541.000000   541.000000
# mean   271.000000        271.000000   31.430684    59.637153   156.484835
# std    156.317519        156.317519    5.411006    11.028287     6.033545
# min      1.000000          1.000000   20.000000    31.000000   137.000000
# 25%    136.000000        136.000000   28.000000    52.000000   152.000000
# 50%    271.000000        271.000000   31.000000    59.000000   156.000000
# 75%    406.000000        406.000000   35.000000    65.000000   160.000000
# max    541.000000        541.000000   48.000000   108.000000   180.000000
#
#        Blood Group  Cycle(R/I)  Cycle length(days)  Marraige Status (Yrs)  \
# count   541.000000  541.000000           541.00000             541.000000
# mean     13.802218    2.560074             4.94085               7.666728
# std       1.840812    0.901950             1.49202               4.810733
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sl. No                 541 non-null    int64
#  1   Patient File No.       541 non-null    int64
#  2    Age (yrs)             541 non-null    int64
#  3   Weight (Kg)            541 non-null    float64
#  4   Height(Cm)             541 non-null    float64
#  5   Blood Group            541 non-null    int64
#  6   Cycle(R/I)             541 non-null    int64
#  7   Cycle length(days)     541 non-null    int64
#  8   Marraige Status (Yrs)  541 non-null    float64
#  9   No. of aborptions      541 non-null    int64
#  10  Weight gain(Y/N)       541 non-null    int64
#  11  hair growth(Y/N)       541 non-null    int64
#  12  Skin darkening (Y/N)   541 non-null    int64
#  13  Hair loss(Y/N)         541 non-null    int64
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X= pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
from sklearn import preprocessing
normalized = preprocessing.normalize(df)
normalized = pd.DataFrame(X,
                         columns=df.columns)

# %%
X
# Out:
#        Sl. No  Patient File No.   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0   -1.728852         -1.728852   -0.634606    -1.364770    -0.744005
# 1   -1.722449         -1.722449    0.845230     0.486731     0.831983
# 2   -1.716046         -1.716046    0.290291     0.831618     1.412610
# 3   -1.709643         -1.709643    1.030210     0.486731    -1.407579
# 4   -1.703240         -1.703240   -1.189545    -0.693147     0.749036
# ..        ...               ...         ...          ...          ...
# 536  1.703240          1.703240    0.660251    -0.874666     1.344925
# 537  1.709643          1.709643   -0.264647     0.323363     0.251356
# 538  1.716046          1.716046    0.845230    -0.511627    -0.744005
# 539  1.722449          1.722449   -0.819586    -0.874666    -1.075792
# 540  1.728852          1.728852   -1.559504     2.029648     1.412610
#
#      Blood Group  Cycle(R/I)  Cycle length(days)  Marraige Status (Yrs)  \
# ...

# %%
X1=d1.drop('PCOS (Y/N)',axis=1)
y1=d1['PCOS (Y/N)']

# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X1,y1,train_size=0.05,random_state=42)

# %%
#LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(X_train,y_train)

print(f"Logistic Regression:{log_model.score(X_test,y_test)}") #accuracy
y_pred = log_model.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('LOGISTIC  REGRESSION')
plt.show()
# Out:
# Logistic Regression:0.5891472868217055
# Confusion Matrix:
# [[55 42]
#  [11 21]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.57      0.67        97
#            1       0.33      0.66      0.44        32
#
#     accuracy                           0.59       129
#    macro avg       0.58      0.61      0.56       129
# weighted avg       0.71      0.59      0.62       129
#
# Accuracy: 0.5891472868217055
#
#                   Confusion Matrix

# %%
#SUPPORT VECTOR MACHINE

from sklearn.svm import SVC
svm = SVC(kernel="rbf", gamma=0.5, C=1.0)
svm.fit(X1, y1)
print(f"Support Vector Machine:{svm.score(X_test,y_test)}") #accuracy
y_pred = svm.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Reds', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('SUPPORT VECTOR MACHINE')
plt.show()
# Out:
# Support Vector Machine:1.0
# Confusion Matrix:
# [[97  0]
#  [ 0 32]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       1.00      1.00      1.00        32
#
#     accuracy                           1.00       129
#    macro avg       1.00      1.00      1.00       129
# weighted avg       1.00      1.00      1.00       129
#
# Accuracy: 1.0
#
#                   Confusion Matrix

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

k_values = [i for i in range (1,31)]
scores = []

scaler = StandardScaler()
X1 = scaler.fit_transform(X1)

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    score = cross_val_score(knn, X1, y1, cv=5)
    scores.append(np.mean(score))

sns.lineplot(x = k_values, y = scores, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("Accuracy Score")
plt.show()

best_index = np.argmax(scores)
best_k = k_values[best_index]

knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\n")
# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix\n")
plt.title('K-Nearest Classifier')
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        97
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.75       129
#    macro avg       0.38      0.50      0.43       129
# weighted avg       0.57      0.75      0.65       129
#
# Accuracy: 0.751937984496124
#
#
#
#                   Confusion Matrix

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

# Making predictions on the test set
y_pred = rf_classifier.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('Random Forest Classifier')
plt.show()
# Out:
# Confusion Matrix:
# [[97  0]
#  [32  0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        97
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.75       129
#    macro avg       0.38      0.50      0.43       129
# weighted avg       0.57      0.75      0.65       129
#
# Accuracy: 0.751937984496124
#
#                   Confusion Matrix

# %%
#DECISION MAKING TREE

from sklearn.tree import DecisionTreeClassifier

# Initializing and training the DECISION MAKING TREE
classifier = DecisionTreeClassifier(random_state=42)
# Training the classifier
classifier.fit(X_train, y_train)

# Predicting the test set results
y_pred = classifier.predict(X_test)

# Generating confusion matrix
con_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification repor\
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(con_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('DECISION MAKING TREE')
plt.show()
# Out:
# Confusion Matrix:
# [[97  0]
#  [32  0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        97
#            1       0.25      0.41      0.31        32
#
#     accuracy                           0.55       129
#    macro avg       0.50      0.50      0.49       129
# weighted avg       0.63      0.55      0.58       129
#
# Accuracy: 0.5503875968992248
#
#                   Confusion Matrix

# %%
from sklearn.decomposition import PCA
# Fit PCA to determine explained variance ratio
pca = PCA()
pca.fit(X)

# Plot scree plot
plt.figure(figsize=(8, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='-')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = df.corr()
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
pca = PCA(n_components=3)  # Assuming you found 2 components to be optimal
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Train a classifier on the transformed data
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = clf.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Random Forest Classifier")
print("Accuracy:", accuracy)
# Out:
# Random Forest Classifier
# Accuracy: 0.6356589147286822

# %%
clf = LogisticRegression()
clf.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = clf.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Logistic Regression")
print("Accuracy:", accuracy)
# Out:
# Logistic Regression
# Accuracy: 0.5891472868217055

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = knn.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("K Nearest Neighbour")
print("Accuracy:", accuracy)
# Out:
# K Nearest Neighbour
# Accuracy: 0.751937984496124

# %%
svm = SVC(kernel="rbf", gamma=0.5, C=1.0)
svm.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred =svm.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Support Vector Machine")
print("Accuracy:", accuracy)
# Out:
# Support Vector Machine
# Accuracy: 0.751937984496124

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = clf.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("DecisionTreeClassifier")
print("Accuracy:", accuracy)
# Out:
# DecisionTreeClassifier
# Accuracy: 0.5968992248062015

# %%
#FOR  270 DATASETS

# %%
X2=d2.drop('PCOS (Y/N)',axis=1)
y2=d2['PCOS (Y/N)']

# %%
X_train,X_test,y_train,y_test=train_test_split(X2,y2,train_size=0.05,random_state=42)

# %%
#LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(X_train,y_train)

print(f"Logistic Regression:{log_model.score(X_test,y_test)}") #accuracy
y_pred = log_model.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('LOGISTIC  REGRESSION')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression:0.6926070038910506
# Confusion Matrix:
# [[140  37]
#  [ 42  38]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78       177
#            1       0.51      0.47      0.49        80
#
#     accuracy                           0.69       257
#    macro avg       0.64      0.63      0.64       257
# weighted avg       0.69      0.69      0.69       257
#
# ...

# %%
#SUPPORT VECTOR MACHINE

from sklearn.svm import SVC
svm = SVC(kernel="rbf", gamma=0.5, C=1.0)
svm.fit(X2, y2)
print(f"Support Vector Machine:{svm.score(X_test,y_test)}") #accuracy
y_pred = svm.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Reds', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('SUPPORT VECTOR MACHINE')
plt.show()
# Out:
# Support Vector Machine:1.0
# Confusion Matrix:
# [[177   0]
#  [  0  80]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       177
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       257
#    macro avg       1.00      1.00      1.00       257
# weighted avg       1.00      1.00      1.00       257
#
# Accuracy: 1.0
#
#                   Confusion Matrix

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score



knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\n")
# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix\n")
plt.title('K-Nearest Classifier')
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.72       177
#            1       0.37      0.36      0.36        80
#
#     accuracy                           0.61       257
#    macro avg       0.54      0.54      0.54       257
# weighted avg       0.61      0.61      0.61       257
#
# Accuracy: 0.6070038910505836
#
#
#
#                   Confusion Matrix

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

# Making predictions on the test set
y_pred = rf_classifier.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('Random Forest Classifier')
plt.show()
# Out:
# Confusion Matrix:
# [[166  11]
#  [ 46  34]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       177
#            1       0.76      0.42      0.54        80
#
#     accuracy                           0.78       257
#    macro avg       0.77      0.68      0.70       257
# weighted avg       0.77      0.78      0.76       257
#
# Accuracy: 0.7782101167315175
#
#                   Confusion Matrix

# %%
#DECISION MAKING TREE

from sklearn.tree import DecisionTreeClassifier

# Initializing and training the DECISION MAKING TREE
classifier = DecisionTreeClassifier(random_state=42)
# Training the classifier
classifier.fit(X_train, y_train)

# Predicting the test set results
y_pred = classifier.predict(X_test)

# Generating confusion matrix
con_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification repor\
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(con_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('DECISION MAKING TREE')
plt.show()
# Out:
# Confusion Matrix:
# [[166  11]
#  [ 46  34]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       177
#            1       0.59      0.42      0.49        80
#
#     accuracy                           0.73       257
#    macro avg       0.68      0.64      0.65       257
# weighted avg       0.71      0.73      0.71       257
#
# Accuracy: 0.7276264591439688
#
#                   Confusion Matrix

# %%
#FOR 405 DATASETS

# %%
X3=d3.drop('PCOS (Y/N)',axis=1)
y3=d3['PCOS (Y/N)']

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y3,train_size=0.05,random_state=42)

# %%
#LOGISTIC REGRESSION MODEL

from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(X_train,y_train)

print(f"Logistic Regression:{log_model.score(X_test,y_test)}") #accuracy
y_pred = log_model.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('LOGISTIC  REGRESSION')
plt.show()
# Out:
# Logistic Regression:0.7373540856031129
# Confusion Matrix:
# [[304  41]
#  [ 94  75]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82       345
#            1       0.65      0.44      0.53       169
#
#     accuracy                           0.74       514
#    macro avg       0.71      0.66      0.67       514
# weighted avg       0.73      0.74      0.72       514
#
# Accuracy: 0.7373540856031129
#
#                   Confusion Matrix

# %%
#SUPPORT VECTOR MACHINE

from sklearn.svm import SVC
svm = SVC(kernel="rbf", gamma=0.5, C=1.0)
svm.fit(X, y)
print(f"Support Vector Machine:{svm.score(X_test,y_test)}") #accuracy
y_pred = svm.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Reds', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('SUPPORT VECTOR MACHINE')
plt.show()
# Out:
# Support Vector Machine:0.9980544747081712
# Confusion Matrix:
# [[345   0]
#  [  1 168]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       345
#            1       1.00      0.99      1.00       169
#
#     accuracy                           1.00       514
#    macro avg       1.00      1.00      1.00       514
# weighted avg       1.00      1.00      1.00       514
#
# Accuracy: 0.9980544747081712
#
#                   Confusion Matrix

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

k_values = [i for i in range (1,40)]
scores = []

scaler = StandardScaler()
X = scaler.fit_transform(X)

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    score = cross_val_score(knn, X, y, cv=5)
    scores.append(np.mean(score))

sns.lineplot(x = k_values, y = scores, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("Accuracy Score")
plt.show()

best_index = np.argmax(scores)
best_k = k_values[best_index]

knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\n")
# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix\n")
plt.title('K-Nearest Classifier')
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       345
#            1       0.00      0.00      0.00       169
#
#     accuracy                           0.67       514
#    macro avg       0.34      0.50      0.40       514
# weighted avg       0.45      0.67      0.54       514
#
# Accuracy: 0.6712062256809338
#
#
#
#                   Confusion Matrix

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

# Making predictions on the test set
y_pred = rf_classifier.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('Random Forest Classifier')
plt.show()
# Out:
# Confusion Matrix:
# [[338   7]
#  [141  28]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.98      0.82       345
#            1       0.80      0.17      0.27       169
#
#     accuracy                           0.71       514
#    macro avg       0.75      0.57      0.55       514
# weighted avg       0.74      0.71      0.64       514
#
# Accuracy: 0.7120622568093385
#
#                   Confusion Matrix

# %%
#DECISION MAKING TREE

from sklearn.tree import DecisionTreeClassifier

# Initializing and training the DECISION MAKING TREE

# Training the classifier
classifier.fit(X_train, y_train)

# Predicting the test set results
y_pred = classifier.predict(X_test)

# Generating confusion matrix
con_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification repor\
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(con_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('DECISION MAKING TREE')
plt.show()
# Out:
# Confusion Matrix:
# [[338   7]
#  [141  28]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81       345
#            1       0.63      0.30      0.41       169
#
#     accuracy                           0.71       514
#    macro avg       0.68      0.61      0.61       514
# weighted avg       0.70      0.71      0.68       514
#
# Accuracy: 0.7120622568093385
#
#                   Confusion Matrix

# %%
#FOR 541 ROWS
X=df.drop('PCOS (Y/N)',axis=1)
y=df['PCOS (Y/N)']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.05,random_state=42)

# %%
#LOGISTIC REGRESSION MODEL

from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(X_train,y_train)

print(f"Logistic Regression:{log_model.score(X_test,y_test)}") #accuracy
y_pred = log_model.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('LOGISTIC  REGRESSION')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression:0.6439688715953308
# Confusion Matrix:
# [[297  48]
#  [135  34]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.86      0.76       345
#            1       0.41      0.20      0.27       169
#
#     accuracy                           0.64       514
#    macro avg       0.55      0.53      0.52       514
# weighted avg       0.60      0.64      0.60       514
#
# ...

# %%
#SUPPORT VECTOR MACHINE

from sklearn.svm import SVC
svm = SVC(kernel="rbf", gamma=0.5, C=1.0)
svm.fit(X, y)
print(f"Support Vector Machine:{svm.score(X_test,y_test)}") #accuracy
y_pred = svm.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Reds', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('SUPPORT VECTOR MACHINE')
plt.show()
# Out:
# Support Vector Machine:1.0
# Confusion Matrix:
# [[345   0]
#  [  0 169]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       345
#            1       1.00      1.00      1.00       169
#
#     accuracy                           1.00       514
#    macro avg       1.00      1.00      1.00       514
# weighted avg       1.00      1.00      1.00       514
#
# Accuracy: 1.0
#
#                   Confusion Matrix

# %%
#K-Nearest Neighbor

# %%
#feature Scaling
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

k_values = [i for i in range (1,40)]
scores = []

scaler = StandardScaler()
X = scaler.fit_transform(X)

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    score = cross_val_score(knn, X, y, cv=5)
    scores.append(np.mean(score))

sns.lineplot(x = k_values, y = scores, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("Accuracy Score")
plt.show()

best_index = np.argmax(scores)
best_k = k_values[best_index]

knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

# Generating classification report
class_report = classification_report(y_test, y_pred,zero_division=0)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\n")
# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix\n")
plt.title('K-Nearest Classifier')
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       345
#            1       0.00      0.00      0.00       169
#
#     accuracy                           0.67       514
#    macro avg       0.34      0.50      0.40       514
# weighted avg       0.45      0.67      0.54       514
#
# Accuracy: 0.6712062256809338
#
#
#
#                   Confusion Matrix

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

# Making predictions on the test set
y_pred = rf_classifier.predict(X_test)

# Generating confusion matrix
co_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(co_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('Random Forest Classifier')
plt.show()
# Out:
# Confusion Matrix:
# [[338   7]
#  [141  28]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.98      0.82       345
#            1       0.80      0.17      0.27       169
#
#     accuracy                           0.71       514
#    macro avg       0.75      0.57      0.55       514
# weighted avg       0.74      0.71      0.64       514
#
# Accuracy: 0.7120622568093385
#
#                   Confusion Matrix

# %%
#DECISION MAKING TREE

from sklearn.tree import DecisionTreeClassifier

# Initializing and training the DECISION MAKING TREE

# Training the classifier
classifier.fit(X_train, y_train)

# Predicting the test set results
y_pred = classifier.predict(X_test)

# Generating confusion matrix
con_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(co_matrix)

# Generating classification repor\
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)


accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
plt.figure(figsize=(5, 4))
sns.heatmap(con_matrix, annot=True, cmap='Greens', fmt='g')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
print("\n                  Confusion Matrix")
plt.title('DECISION MAKING TREE')
plt.show()
# Out:
# Confusion Matrix:
# [[338   7]
#  [141  28]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81       345
#            1       0.63      0.30      0.41       169
#
#     accuracy                           0.71       514
#    macro avg       0.68      0.61      0.61       514
# weighted avg       0.70      0.71      0.68       514
#
# Accuracy: 0.7120622568093385
#
#                   Confusion Matrix

# %%
pca = PCA(n_components=3)  # Assuming you found 2 components to be optimal
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Train a classifier on the transformed data
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = clf.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Random Forest Classifier")
print("Accuracy:", accuracy)
# Out:
# Random Forest Classifier
# Accuracy: 0.6750972762645915

# %%
clf = LogisticRegression()
clf.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = clf.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Logistic Regression")
print("Accuracy:", accuracy)
# Out:
# Logistic Regression
# Accuracy: 0.6789883268482491

# %%
knn = KNeighborsClassifier(n_neighbors=21)
knn.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = knn.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("K Nearest Neighbour")
print("Accuracy:", accuracy)
# Out:
# K Nearest Neighbour
# Accuracy: 0.6712062256809338

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred = clf.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("DecisionTreeClassifier")
print("Accuracy:", accuracy)
# Out:
# DecisionTreeClassifier
# Accuracy: 0.603112840466926

# %%
svm = SVC(kernel="rbf", gamma=0.5, C=1.0)
svm.fit(X_train_pca, y_train)

# Predict on the testing set
y_pred =svm.predict(X_test_pca)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Support Vector Machine")
print("Accuracy:", accuracy)
# Out:
# Support Vector Machine
# Accuracy: 0.6712062256809338

# %%
df.columns
# Out:
# Index(['Sl. No', 'Patient File No.', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'Blood Group', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'No. of aborptions', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'I beta-HCG(mIU/mL)', 'Fast food (Y/N)', 'LH(mIU/mL)',
#        'FSH(mIU/mL)', 'Reg.Exercise(Y/N)', 'Pregnant(Y/N)', 'PCOS (Y/N)'],
#       dtype='object')

# %%
model = SVC(kernel="rbf", gamma=0.5, C=1.0)
model.fit(X_train,y_train)
# Out:
# SVC(gamma=0.5)

# %%
y_pred=model.predict(X_test)

# %%
 new_data= np.array([1,1,26,44.6,152,15,2,5,7,0,0,0,0,0,0,1.99,1,3.68,7.95,0,0])
 reshaped_array =  new_data.reshape(1, 21)
 new_data_predictions =model.predict( reshaped_array)
if(new_data_predictions==1):
    print("The person has PCOS.")
if(new_data_predictions==0):
    print("The person does not has PCOS.")
# Out:
# The person does not has PCOS.

# %%
 new_data= np.array([3,3,33,68.8,165,11,2,5,10,0,0,0,0,1,1,494.08,1,0.66,5.54,0,1])
 reshaped_array =  new_data.reshape(1, 21)
 new_data_predictions =model.predict( reshaped_array)
if(new_data_predictions==1):
    print("The person has PCOS.")
if(new_data_predictions==0):
    print("The person does not has PCOS.")
# Out:
# The person does not has PCOS.
